# %% [markdown]
# ## 1. Ler os dados

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r'C:\Users\Diego\Downloads\Real_State_Properati.csv', sep = '\t')
df
# Out:
#       property_type     place_name country_name       state_name        lat  \
# 0                PH      Mataderos    Argentina  Capital Federal -34.661824
# 1         apartment      Mataderos    Argentina  Capital Federal -34.652262
# 2         apartment       Belgrano    Argentina  Capital Federal -34.559873
# 3         apartment       Belgrano    Argentina  Capital Federal -34.559873
# 4                PH      Mataderos    Argentina  Capital Federal -34.652356
# ...             ...            ...          ...              ...        ...
# 17218     apartment   Barrio Norte    Argentina  Capital Federal -34.599214
# 17219     apartment       Recoleta    Argentina  Capital Federal -34.587425
# 17220     apartment       Belgrano    Argentina  Capital Federal -34.563685
# 17221     apartment       Belgrano    Argentina  Capital Federal -34.563685
# 17222     apartment  Villa Urquiza    Argentina  Capital Federal -34.570639
#
#              lon     price currency  surface_total_in_m2
# 0     -58.508839   62000.0      USD                 55.0
# 1     -58.522982   72000.0      USD                 55.0
# 2     -58.443362  138000.0      USD                 45.0
# 3     -58.443362  195000.0      USD                 65.0
# 4     -58.501624  239000.0      USD                140.0
# ...          ...       ...      ...                  ...
# 17218 -58.402519  165000.0      USD                 91.0
# 17219 -58.397372  165000.0      USD                 44.0
# 17220 -58.442683  410000.0      USD                157.0
# 17221 -58.442683  410000.0      USD                157.0
# 17222 -58.475596  131500.0      USD                 46.0
#
# [17223 rows x 9 columns]

# %% [markdown]
# ## 2. Substituir os valores zerados pela média dos pares

# %%
dfdiffsurfacezerado = df['surface_total_in_m2'] != 0 
df2 = df[dfdiffsurfacezerado]
dfGroup = df2.groupby(['property_type', 'place_name']).mean('surface_total_in_m2')
dfmerge = pd.merge(df, dfGroup, on=['property_type', 'place_name'])
dfmerge = dfmerge.rename(columns={'surface_total_in_m2_y': 'surface_total_in_m2_media'})
dfmerge
# Out:
#       property_type     place_name country_name       state_name      lat_x  \
# 0                PH      Mataderos    Argentina  Capital Federal -34.661824
# 1                PH      Mataderos    Argentina  Capital Federal -34.652356
# 2                PH      Mataderos    Argentina  Capital Federal -34.657242
# 3                PH      Mataderos    Argentina  Capital Federal -34.650604
# 4                PH      Mataderos    Argentina  Capital Federal -34.656920
# ...             ...            ...          ...              ...        ...
# 17218            PH  Palermo Viejo    Argentina  Capital Federal -34.592963
# 17219            PH    Parque Chas    Argentina  Capital Federal -34.585679
# 17220            PH  Palermo Chico    Argentina  Capital Federal -34.580888
# 17221         store      Agronomía    Argentina  Capital Federal -34.588465
# 17222         house      Agronomía    Argentina  Capital Federal -34.590822
#
#            lon_x   price_x currency  surface_total_in_m2_x      lat_y  \
# 0     -58.508839   62000.0      USD                   55.0 -34.653567
# 1     -58.501624  239000.0      USD                  140.0 -34.653567
# 2     -58.502971   53000.0      USD                   28.0 -34.653567
# 3     -58.496146  245000.0      USD                  326.0 -34.653567
# 4     -58.489784  165000.0      USD                  150.0 -34.653567
# ...          ...       ...      ...                    ...        ...
# 17218 -58.430450  330000.0      USD                  143.0 -34.594894
# 17219 -58.476317  270000.0      USD                  150.0 -34.585679
# 17220 -58.410504  695000.0      USD                  348.0 -34.580888
# 17221 -58.485428  420000.0      USD                  350.0 -34.588465
# 17222 -58.487440  425000.0      USD                  494.0 -34.590822
#
#            lon_y        price_y  surface_total_in_m2_media
# 0     -58.501810  119049.180328                 100.442623
# 1     -58.501810  119049.180328                 100.442623
# 2     -58.501810  119049.180328                 100.442623
# 3     -58.501810  119049.180328                 100.442623
# 4     -58.501810  119049.180328                 100.442623
# ...          ...            ...                        ...
# 17218 -58.422291  254500.000000                 131.500000
# 17219 -58.476317  270000.000000                 150.000000
# 17220 -58.410504  695000.000000                 348.000000
# 17221 -58.485428  420000.000000                 350.000000
# 17222 -58.487440  425000.000000                 494.000000
#
# [17223 rows x 13 columns]

# %%
dfmerge['surface_total_in_m2_Final'] = np.where(dfmerge['surface_total_in_m2_x']== 0, dfmerge['surface_total_in_m2_media'] , dfmerge['surface_total_in_m2_x'])
dfmerge
# Out:
#       property_type     place_name country_name       state_name      lat_x  \
# 0                PH      Mataderos    Argentina  Capital Federal -34.661824
# 1                PH      Mataderos    Argentina  Capital Federal -34.652356
# 2                PH      Mataderos    Argentina  Capital Federal -34.657242
# 3                PH      Mataderos    Argentina  Capital Federal -34.650604
# 4                PH      Mataderos    Argentina  Capital Federal -34.656920
# ...             ...            ...          ...              ...        ...
# 17218            PH  Palermo Viejo    Argentina  Capital Federal -34.592963
# 17219            PH    Parque Chas    Argentina  Capital Federal -34.585679
# 17220            PH  Palermo Chico    Argentina  Capital Federal -34.580888
# 17221         store      Agronomía    Argentina  Capital Federal -34.588465
# 17222         house      Agronomía    Argentina  Capital Federal -34.590822
#
#            lon_x   price_x currency  surface_total_in_m2_x      lat_y  \
# 0     -58.508839   62000.0      USD                   55.0 -34.653567
# 1     -58.501624  239000.0      USD                  140.0 -34.653567
# 2     -58.502971   53000.0      USD                   28.0 -34.653567
# 3     -58.496146  245000.0      USD                  326.0 -34.653567
# 4     -58.489784  165000.0      USD                  150.0 -34.653567
# ...          ...       ...      ...                    ...        ...
# 17218 -58.430450  330000.0      USD                  143.0 -34.594894
# 17219 -58.476317  270000.0      USD                  150.0 -34.585679
# 17220 -58.410504  695000.0      USD                  348.0 -34.580888
# 17221 -58.485428  420000.0      USD                  350.0 -34.588465
# 17222 -58.487440  425000.0      USD                  494.0 -34.590822
#
#            lon_y        price_y  surface_total_in_m2_media  \
# 0     -58.501810  119049.180328                 100.442623
# 1     -58.501810  119049.180328                 100.442623
# 2     -58.501810  119049.180328                 100.442623
# 3     -58.501810  119049.180328                 100.442623
# 4     -58.501810  119049.180328                 100.442623
# ...          ...            ...                        ...
# 17218 -58.422291  254500.000000                 131.500000
# 17219 -58.476317  270000.000000                 150.000000
# 17220 -58.410504  695000.000000                 348.000000
# 17221 -58.485428  420000.000000                 350.000000
# 17222 -58.487440  425000.000000                 494.000000
#
#        surface_total_in_m2_Final
# 0                           55.0
# 1                          140.0
# 2                           28.0
# 3                          326.0
# 4                          150.0
# ...                          ...
# 17218                      143.0
# 17219                      150.0
# 17220                      348.0
# 17221                      350.0
# 17222                      494.0
#
# [17223 rows x 14 columns]

# %% [markdown]
# ## 3.Preço M²

# %%
dfmerge['Preco_M2'] = dfmerge['price_x'] / dfmerge['surface_total_in_m2_Final']
dfmerge
# Out:
#       property_type     place_name country_name       state_name      lat_x  \
# 0                PH      Mataderos    Argentina  Capital Federal -34.661824
# 1                PH      Mataderos    Argentina  Capital Federal -34.652356
# 2                PH      Mataderos    Argentina  Capital Federal -34.657242
# 3                PH      Mataderos    Argentina  Capital Federal -34.650604
# 4                PH      Mataderos    Argentina  Capital Federal -34.656920
# ...             ...            ...          ...              ...        ...
# 17218            PH  Palermo Viejo    Argentina  Capital Federal -34.592963
# 17219            PH    Parque Chas    Argentina  Capital Federal -34.585679
# 17220            PH  Palermo Chico    Argentina  Capital Federal -34.580888
# 17221         store      Agronomía    Argentina  Capital Federal -34.588465
# 17222         house      Agronomía    Argentina  Capital Federal -34.590822
#
#            lon_x   price_x currency  surface_total_in_m2_x      lat_y  \
# 0     -58.508839   62000.0      USD                   55.0 -34.653567
# 1     -58.501624  239000.0      USD                  140.0 -34.653567
# 2     -58.502971   53000.0      USD                   28.0 -34.653567
# 3     -58.496146  245000.0      USD                  326.0 -34.653567
# 4     -58.489784  165000.0      USD                  150.0 -34.653567
# ...          ...       ...      ...                    ...        ...
# 17218 -58.430450  330000.0      USD                  143.0 -34.594894
# 17219 -58.476317  270000.0      USD                  150.0 -34.585679
# 17220 -58.410504  695000.0      USD                  348.0 -34.580888
# 17221 -58.485428  420000.0      USD                  350.0 -34.588465
# 17222 -58.487440  425000.0      USD                  494.0 -34.590822
#
#            lon_y        price_y  surface_total_in_m2_media  \
# 0     -58.501810  119049.180328                 100.442623
# 1     -58.501810  119049.180328                 100.442623
# 2     -58.501810  119049.180328                 100.442623
# 3     -58.501810  119049.180328                 100.442623
# 4     -58.501810  119049.180328                 100.442623
# ...          ...            ...                        ...
# 17218 -58.422291  254500.000000                 131.500000
# 17219 -58.476317  270000.000000                 150.000000
# 17220 -58.410504  695000.000000                 348.000000
# 17221 -58.485428  420000.000000                 350.000000
# 17222 -58.487440  425000.000000                 494.000000
#
#        surface_total_in_m2_Final     Preco_M2
# 0                           55.0  1127.272727
# 1                          140.0  1707.142857
# 2                           28.0  1892.857143
# 3                          326.0   751.533742
# 4                          150.0  1100.000000
# ...                          ...          ...
# 17218                      143.0  2307.692308
# 17219                      150.0  1800.000000
# 17220                      348.0  1997.126437
# 17221                      350.0  1200.000000
# 17222                      494.0   860.323887
#
# [17223 rows x 15 columns]

# %%
dfmerge
# Out:
#       property_type     place_name country_name       state_name      lat_x  \
# 0                PH      Mataderos    Argentina  Capital Federal -34.661824
# 1                PH      Mataderos    Argentina  Capital Federal -34.652356
# 2                PH      Mataderos    Argentina  Capital Federal -34.657242
# 3                PH      Mataderos    Argentina  Capital Federal -34.650604
# 4                PH      Mataderos    Argentina  Capital Federal -34.656920
# ...             ...            ...          ...              ...        ...
# 17218            PH  Palermo Viejo    Argentina  Capital Federal -34.592963
# 17219            PH    Parque Chas    Argentina  Capital Federal -34.585679
# 17220            PH  Palermo Chico    Argentina  Capital Federal -34.580888
# 17221         store      Agronomía    Argentina  Capital Federal -34.588465
# 17222         house      Agronomía    Argentina  Capital Federal -34.590822
#
#            lon_x   price_x currency  surface_total_in_m2_x      lat_y  \
# 0     -58.508839   62000.0      USD                   55.0 -34.653567
# 1     -58.501624  239000.0      USD                  140.0 -34.653567
# 2     -58.502971   53000.0      USD                   28.0 -34.653567
# 3     -58.496146  245000.0      USD                  326.0 -34.653567
# 4     -58.489784  165000.0      USD                  150.0 -34.653567
# ...          ...       ...      ...                    ...        ...
# 17218 -58.430450  330000.0      USD                  143.0 -34.594894
# 17219 -58.476317  270000.0      USD                  150.0 -34.585679
# 17220 -58.410504  695000.0      USD                  348.0 -34.580888
# 17221 -58.485428  420000.0      USD                  350.0 -34.588465
# 17222 -58.487440  425000.0      USD                  494.0 -34.590822
#
#            lon_y        price_y  surface_total_in_m2_media  \
# 0     -58.501810  119049.180328                 100.442623
# 1     -58.501810  119049.180328                 100.442623
# 2     -58.501810  119049.180328                 100.442623
# 3     -58.501810  119049.180328                 100.442623
# 4     -58.501810  119049.180328                 100.442623
# ...          ...            ...                        ...
# 17218 -58.422291  254500.000000                 131.500000
# 17219 -58.476317  270000.000000                 150.000000
# 17220 -58.410504  695000.000000                 348.000000
# 17221 -58.485428  420000.000000                 350.000000
# 17222 -58.487440  425000.000000                 494.000000
#
#        surface_total_in_m2_Final     Preco_M2
# 0                           55.0  1127.272727
# 1                          140.0  1707.142857
# 2                           28.0  1892.857143
# 3                          326.0   751.533742
# 4                          150.0  1100.000000
# ...                          ...          ...
# 17218                      143.0  2307.692308
# 17219                      150.0  1800.000000
# 17220                      348.0  1997.126437
# 17221                      350.0  1200.000000
# 17222                      494.0   860.323887
#
# [17223 rows x 15 columns]
